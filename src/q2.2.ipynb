# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Function for one-hot encoding
def encode_one_hot(labels):
    num_samples = labels.shape[0]
    num_classes = 10  # Assuming 10 classes (0-9)
    encoded = np.zeros((num_samples, num_classes), dtype=int)
    encoded[np.arange(num_samples), labels] = 1
    return encoded

# Function to read pixel data
def load_pixel_data(file_path):
    with open(file_path, 'rb') as f:
        data = np.frombuffer(f.read(), dtype=np.uint8, offset=16)
    return data.reshape(-1, 784).astype('float32') / 255.0

# Function to read label data
def load_label_data(file_path):
    with open(file_path, 'rb') as f:
        labels = np.frombuffer(f.read(), dtype=np.uint8, offset=8)
    return encode_one_hot(labels)

# Function to load MNIST dataset
def load_data(base_path):
    X_train = load_pixel_data(os.path.join(base_path, "train-images-idx3-ubyte"))
    y_train = load_label_data(os.path.join(base_path, "train-labels-idx1-ubyte"))
    X_test = load_pixel_data(os.path.join(base_path, "t10k-images-idx3-ubyte"))
    y_test = load_label_data(os.path.join(base_path, "t10k-labels-idx1-ubyte"))
    return X_train, y_train, X_test, y_test

# Logistic Regression Model
class LogisticModel:
    def __init__(self, lr=1e-3, reg=1e-4, num_epochs=100, batch=200, input_size=784, num_classes=10):
        self.lr = lr
        self.reg = reg
        self.epochs = num_epochs
        self.batch_size = batch
        self.weights = np.random.randn(input_size, num_classes)
        self.biases = np.zeros((1, num_classes))

    def softmax(self, z):
        exp_z = np.exp(z - np.max(z, axis=1, keepdims=True))
        return exp_z / np.sum(exp_z, axis=1, keepdims=True)

    def train(self, X_train, y_train, X_val, y_val):
        num_samples = X_train.shape[0]
        accuracies = []
        for epoch in range(self.epochs):
            indices = np.random.permutation(num_samples)
            X_train, y_train = X_train[indices], y_train[indices]

            for start in range(0, num_samples, self.batch_size):
                end = start + self.batch_size
                X_batch, y_batch = X_train[start:end], y_train[start:end]

                # Forward pass
                logits = np.dot(X_batch, self.weights) + self.biases
                predictions = self.softmax(logits)

                # Gradients
                error = predictions - y_batch
                grad_weights = np.dot(X_batch.T, error) / self.batch_size + self.reg * self.weights
                grad_biases = np.sum(error, axis=0, keepdims=True) / self.batch_size

                # Update weights and biases
                self.weights -= self.lr * grad_weights
                self.biases -= self.lr * grad_biases

            val_accuracy, _ = self.evaluate(X_val, y_val)
            accuracies.append(val_accuracy)
            print(f"Epoch {epoch + 1}/{self.epochs}, Validation Accuracy: {val_accuracy:.4f}")
        return accuracies

    def predict(self, X):
        logits = np.dot(X, self.weights) + self.biases
        return np.argmax(self.softmax(logits), axis=1)

    def evaluate(self, X, y_true):
        y_pred = self.predict(X)
        y_true_labels = np.argmax(y_true, axis=1)
        accuracy = np.mean(y_true_labels == y_pred)
        return accuracy, self.conf_matrix(y_true_labels, y_pred)

    @staticmethod
    def conf_matrix(y_true, y_pred):
        num_classes = np.max(y_true) + 1
        cm = np.zeros((num_classes, num_classes), dtype=int)
        for true_label, pred_label in zip(y_true, y_pred):
            cm[true_label, pred_label] += 1
        return cm

# Plot accuracy for different batch sizes
def plot_accuracies(batch_results):
    plt.figure(figsize=(10, 6))
    for batch_size, accuracies in batch_results.items():
        plt.plot(range(1, len(accuracies) + 1), accuracies, label=f"Batch Size: {batch_size}")
    plt.title("Validation Accuracy vs. Epochs for Different Batch Sizes")
    plt.xlabel("Epochs")
    plt.ylabel("Validation Accuracy")
    plt.legend()
    plt.grid()
    plt.show()

# Experiment with batch sizes
def batch_size_experiment(X_train, y_train, X_val, y_val, params):
    batch_sizes = [1, 64, 3000]
    results = {}
    for batch in batch_sizes:
        print(f"\nBatch Size Experiment: {batch}")
        model = LogisticModel(batch=batch, **params)
        results[batch] = model.train(X_train, y_train, X_val, y_val)
    plot_accuracies(results)

# Main function to run experiments
def main():
    dataset_path = "/Users/elifsorguc/Desktop/Bilkent/ML/MachineLearning-PCA-LogReg/data/mnist"
    X_train, y_train, X_test, y_test = load_data(dataset_path)
    X_val, y_val = X_train[:10000], y_train[:10000]
    X_train, y_train = X_train[10000:], y_train[10000:]

    params = {
        'lr': 5e-4,
        'reg': 1e-4,
        'num_epochs': 100,
        'input_size': 784,
        'num_classes': 10
    }

    batch_size_experiment(X_train, y_train, X_val, y_val, params)

if __name__ == "__main__":
    main()
# Out:
# Batch Size Experiment: 1
# Epoch 1/100, Validation Accuracy: 0.6140
# Epoch 2/100, Validation Accuracy: 0.6727
# Epoch 3/100, Validation Accuracy: 0.7033
# Epoch 4/100, Validation Accuracy: 0.7182
# Epoch 5/100, Validation Accuracy: 0.7325
# Epoch 6/100, Validation Accuracy: 0.7424
# Epoch 7/100, Validation Accuracy: 0.7477
# Epoch 8/100, Validation Accuracy: 0.7557
# Epoch 9/100, Validation Accuracy: 0.7606
# Epoch 10/100, Validation Accuracy: 0.7648
# Epoch 11/100, Validation Accuracy: 0.7691
# Epoch 12/100, Validation Accuracy: 0.7691
# Epoch 13/100, Validation Accuracy: 0.7737
# Epoch 14/100, Validation Accuracy: 0.7785
# Epoch 15/100, Validation Accuracy: 0.7769
# Epoch 16/100, Validation Accuracy: 0.7810
# Epoch 17/100, Validation Accuracy: 0.7797
# Epoch 18/100, Validation Accuracy: 0.7855
# Epoch 19/100, Validation Accuracy: 0.7844
# Epoch 20/100, Validation Accuracy: 0.7856
# Epoch 21/100, Validation Accuracy: 0.7884
# Epoch 22/100, Validation Accuracy: 0.7891
# Epoch 23/100, Validation Accuracy: 0.7927
# Epoch 24/100, Validation Accuracy: 0.7934
# Epoch 25/100, Validation Accuracy: 0.7937
# Epoch 26/100, Validation Accuracy: 0.7960
# Epoch 27/100, Validation Accuracy: 0.7995
# Epoch 28/100, Validation Accuracy: 0.7998
# Epoch 29/100, Validation Accuracy: 0.7984
# Epoch 30/100, Validation Accuracy: 0.7985
# Epoch 31/100, Validation Accuracy: 0.8011
# Epoch 32/100, Validation Accuracy: 0.8025
# Epoch 33/100, Validation Accuracy: 0.8014
# Epoch 34/100, Validation Accuracy: 0.8053
# Epoch 35/100, Validation Accuracy: 0.8047
# Epoch 36/100, Validation Accuracy: 0.8065
# Epoch 37/100, Validation Accuracy: 0.8066
# Epoch 38/100, Validation Accuracy: 0.8082
# Epoch 39/100, Validation Accuracy: 0.8118
# Epoch 40/100, Validation Accuracy: 0.8098
# Epoch 41/100, Validation Accuracy: 0.8122
# Epoch 42/100, Validation Accuracy: 0.8118
# Epoch 43/100, Validation Accuracy: 0.8121
# Epoch 44/100, Validation Accuracy: 0.8139
# Epoch 45/100, Validation Accuracy: 0.8137
# Epoch 46/100, Validation Accuracy: 0.8138
# Epoch 47/100, Validation Accuracy: 0.8142
# Epoch 48/100, Validation Accuracy: 0.8155
# Epoch 49/100, Validation Accuracy: 0.8171
# Epoch 50/100, Validation Accuracy: 0.8178
# Epoch 51/100, Validation Accuracy: 0.8175
# Epoch 52/100, Validation Accuracy: 0.8176
# Epoch 53/100, Validation Accuracy: 0.8176
# Epoch 54/100, Validation Accuracy: 0.8185
# Epoch 55/100, Validation Accuracy: 0.8189
# Epoch 56/100, Validation Accuracy: 0.8201
# Epoch 57/100, Validation Accuracy: 0.8204
# Epoch 58/100, Validation Accuracy: 0.8208
# Epoch 59/100, Validation Accuracy: 0.8188
# Epoch 60/100, Validation Accuracy: 0.8191
# Epoch 61/100, Validation Accuracy: 0.8209
# Epoch 62/100, Validation Accuracy: 0.8183
# Epoch 63/100, Validation Accuracy: 0.8218
# Epoch 64/100, Validation Accuracy: 0.8231
# Epoch 65/100, Validation Accuracy: 0.8227
# Epoch 66/100, Validation Accuracy: 0.8211
# Epoch 67/100, Validation Accuracy: 0.8247
# Epoch 68/100, Validation Accuracy: 0.8249
# Epoch 69/100, Validation Accuracy: 0.8230
# Epoch 70/100, Validation Accuracy: 0.8233
# Epoch 71/100, Validation Accuracy: 0.8267
# Epoch 72/100, Validation Accuracy: 0.8262
# Epoch 73/100, Validation Accuracy: 0.8253
# Epoch 74/100, Validation Accuracy: 0.8273
# Epoch 75/100, Validation Accuracy: 0.8271
# Epoch 76/100, Validation Accuracy: 0.8272
# Epoch 77/100, Validation Accuracy: 0.8251
# Epoch 78/100, Validation Accuracy: 0.8246
# Epoch 79/100, Validation Accuracy: 0.8278
# Epoch 80/100, Validation Accuracy: 0.8262
# Epoch 81/100, Validation Accuracy: 0.8277
# Epoch 82/100, Validation Accuracy: 0.8307
# Epoch 83/100, Validation Accuracy: 0.8250
# Epoch 84/100, Validation Accuracy: 0.8283
# Epoch 85/100, Validation Accuracy: 0.8295
# Epoch 86/100, Validation Accuracy: 0.8308
# Epoch 87/100, Validation Accuracy: 0.8273
# Epoch 88/100, Validation Accuracy: 0.8293
# Epoch 89/100, Validation Accuracy: 0.8277
# Epoch 90/100, Validation Accuracy: 0.8305
# Epoch 91/100, Validation Accuracy: 0.8289
# Epoch 92/100, Validation Accuracy: 0.8306
# Epoch 93/100, Validation Accuracy: 0.8313
# Epoch 94/100, Validation Accuracy: 0.8339
# Epoch 95/100, Validation Accuracy: 0.8305
# Epoch 96/100, Validation Accuracy: 0.8318
# Epoch 97/100, Validation Accuracy: 0.8304
# Epoch 98/100, Validation Accuracy: 0.8329
# Epoch 99/100, Validation Accuracy: 0.8333
# Epoch 100/100, Validation Accuracy: 0.8315
#
# Batch Size Experiment: 64
# Epoch 1/100, Validation Accuracy: 0.1307
# Epoch 2/100, Validation Accuracy: 0.1591
# Epoch 3/100, Validation Accuracy: 0.1780
# Epoch 4/100, Validation Accuracy: 0.1985
# Epoch 5/100, Validation Accuracy: 0.2211
# Epoch 6/100, Validation Accuracy: 0.2484
# Epoch 7/100, Validation Accuracy: 0.2733
# Epoch 8/100, Validation Accuracy: 0.2929
# Epoch 9/100, Validation Accuracy: 0.3111
# Epoch 10/100, Validation Accuracy: 0.3239
# Epoch 11/100, Validation Accuracy: 0.3372
# Epoch 12/100, Validation Accuracy: 0.3518
# Epoch 13/100, Validation Accuracy: 0.3637
# Epoch 14/100, Validation Accuracy: 0.3744
# Epoch 15/100, Validation Accuracy: 0.3852
# Epoch 16/100, Validation Accuracy: 0.3960
# Epoch 17/100, Validation Accuracy: 0.4060
# Epoch 18/100, Validation Accuracy: 0.4152
# Epoch 19/100, Validation Accuracy: 0.4230
# Epoch 20/100, Validation Accuracy: 0.4320
# Epoch 21/100, Validation Accuracy: 0.4396
# Epoch 22/100, Validation Accuracy: 0.4454
# Epoch 23/100, Validation Accuracy: 0.4556
# Epoch 24/100, Validation Accuracy: 0.4625
# Epoch 25/100, Validation Accuracy: 0.4683
# Epoch 26/100, Validation Accuracy: 0.4743
# Epoch 27/100, Validation Accuracy: 0.4800
# Epoch 28/100, Validation Accuracy: 0.4859
# Epoch 29/100, Validation Accuracy: 0.4921
# Epoch 30/100, Validation Accuracy: 0.4953
# Epoch 31/100, Validation Accuracy: 0.4996
# Epoch 32/100, Validation Accuracy: 0.5044
# Epoch 33/100, Validation Accuracy: 0.5079
# Epoch 34/100, Validation Accuracy: 0.5117
# Epoch 35/100, Validation Accuracy: 0.5166
# Epoch 36/100, Validation Accuracy: 0.5192
# Epoch 37/100, Validation Accuracy: 0.5229
# Epoch 38/100, Validation Accuracy: 0.5262
# Epoch 39/100, Validation Accuracy: 0.5303
# Epoch 40/100, Validation Accuracy: 0.5335
# Epoch 41/100, Validation Accuracy: 0.5360
# Epoch 42/100, Validation Accuracy: 0.5388
# Epoch 43/100, Validation Accuracy: 0.5416
# Epoch 44/100, Validation Accuracy: 0.5448
# Epoch 45/100, Validation Accuracy: 0.5474
# Epoch 46/100, Validation Accuracy: 0.5497
# Epoch 47/100, Validation Accuracy: 0.5531
# Epoch 48/100, Validation Accuracy: 0.5556
# Epoch 49/100, Validation Accuracy: 0.5581
# Epoch 50/100, Validation Accuracy: 0.5613
# Epoch 51/100, Validation Accuracy: 0.5638
# Epoch 52/100, Validation Accuracy: 0.5652
# Epoch 53/100, Validation Accuracy: 0.5681
# Epoch 54/100, Validation Accuracy: 0.5708
# Epoch 55/100, Validation Accuracy: 0.5728
# Epoch 56/100, Validation Accuracy: 0.5741
# Epoch 57/100, Validation Accuracy: 0.5774
# Epoch 58/100, Validation Accuracy: 0.5787
# Epoch 59/100, Validation Accuracy: 0.5806
# Epoch 60/100, Validation Accuracy: 0.5818
# Epoch 61/100, Validation Accuracy: 0.5838
# Epoch 62/100, Validation Accuracy: 0.5859
# Epoch 63/100, Validation Accuracy: 0.5874
# Epoch 64/100, Validation Accuracy: 0.5881
# Epoch 65/100, Validation Accuracy: 0.5902
# Epoch 66/100, Validation Accuracy: 0.5920
# Epoch 67/100, Validation Accuracy: 0.5941
# Epoch 68/100, Validation Accuracy: 0.5962
# Epoch 69/100, Validation Accuracy: 0.5985
# Epoch 70/100, Validation Accuracy: 0.6013
# Epoch 71/100, Validation Accuracy: 0.6030
# Epoch 72/100, Validation Accuracy: 0.6043
# Epoch 73/100, Validation Accuracy: 0.6056
# Epoch 74/100, Validation Accuracy: 0.6067
# Epoch 75/100, Validation Accuracy: 0.6086
# Epoch 76/100, Validation Accuracy: 0.6103
# Epoch 77/100, Validation Accuracy: 0.6113
# Epoch 78/100, Validation Accuracy: 0.6127
# Epoch 79/100, Validation Accuracy: 0.6141
# Epoch 80/100, Validation Accuracy: 0.6153
# Epoch 81/100, Validation Accuracy: 0.6165
# Epoch 82/100, Validation Accuracy: 0.6185
# Epoch 83/100, Validation Accuracy: 0.6204
# Epoch 84/100, Validation Accuracy: 0.6220
# Epoch 85/100, Validation Accuracy: 0.6233
# Epoch 86/100, Validation Accuracy: 0.6239
# Epoch 87/100, Validation Accuracy: 0.6267
# Epoch 88/100, Validation Accuracy: 0.6275
# Epoch 89/100, Validation Accuracy: 0.6289
# Epoch 90/100, Validation Accuracy: 0.6304
# Epoch 91/100, Validation Accuracy: 0.6321
# Epoch 92/100, Validation Accuracy: 0.6326
# Epoch 93/100, Validation Accuracy: 0.6342
# Epoch 94/100, Validation Accuracy: 0.6340
# Epoch 95/100, Validation Accuracy: 0.6356
# Epoch 96/100, Validation Accuracy: 0.6365
# Epoch 97/100, Validation Accuracy: 0.6375
# Epoch 98/100, Validation Accuracy: 0.6384
# Epoch 99/100, Validation Accuracy: 0.6394
# Epoch 100/100, Validation Accuracy: 0.6402
#
# Batch Size Experiment: 3000
# Epoch 1/100, Validation Accuracy: 0.0292
# Epoch 2/100, Validation Accuracy: 0.0276
# Epoch 3/100, Validation Accuracy: 0.0270
# Epoch 4/100, Validation Accuracy: 0.0258
# Epoch 5/100, Validation Accuracy: 0.0248
# Epoch 6/100, Validation Accuracy: 0.0246
# Epoch 7/100, Validation Accuracy: 0.0243
# Epoch 8/100, Validation Accuracy: 0.0237
# Epoch 9/100, Validation Accuracy: 0.0234
# Epoch 10/100, Validation Accuracy: 0.0226
# Epoch 11/100, Validation Accuracy: 0.0218
# Epoch 12/100, Validation Accuracy: 0.0214
# Epoch 13/100, Validation Accuracy: 0.0214
# Epoch 14/100, Validation Accuracy: 0.0212
# Epoch 15/100, Validation Accuracy: 0.0218
# Epoch 16/100, Validation Accuracy: 0.0223
# Epoch 17/100, Validation Accuracy: 0.0223
# Epoch 18/100, Validation Accuracy: 0.0222
# Epoch 19/100, Validation Accuracy: 0.0225
# Epoch 20/100, Validation Accuracy: 0.0226
# Epoch 21/100, Validation Accuracy: 0.0229
# Epoch 22/100, Validation Accuracy: 0.0230
# Epoch 23/100, Validation Accuracy: 0.0235
# Epoch 24/100, Validation Accuracy: 0.0241
# Epoch 25/100, Validation Accuracy: 0.0241
# Epoch 26/100, Validation Accuracy: 0.0252
# Epoch 27/100, Validation Accuracy: 0.0251
# Epoch 28/100, Validation Accuracy: 0.0261
# Epoch 29/100, Validation Accuracy: 0.0266
# Epoch 30/100, Validation Accuracy: 0.0269
# Epoch 31/100, Validation Accuracy: 0.0270
# Epoch 32/100, Validation Accuracy: 0.0271
# Epoch 33/100, Validation Accuracy: 0.0275
# Epoch 34/100, Validation Accuracy: 0.0281
# Epoch 35/100, Validation Accuracy: 0.0290
# Epoch 36/100, Validation Accuracy: 0.0299
# Epoch 37/100, Validation Accuracy: 0.0303
# Epoch 38/100, Validation Accuracy: 0.0314
# Epoch 39/100, Validation Accuracy: 0.0324
# Epoch 40/100, Validation Accuracy: 0.0329
# Epoch 41/100, Validation Accuracy: 0.0342
# Epoch 42/100, Validation Accuracy: 0.0354
# Epoch 43/100, Validation Accuracy: 0.0365
# Epoch 44/100, Validation Accuracy: 0.0374
# Epoch 45/100, Validation Accuracy: 0.0387
# Epoch 46/100, Validation Accuracy: 0.0399
# Epoch 47/100, Validation Accuracy: 0.0415
# Epoch 48/100, Validation Accuracy: 0.0427
# Epoch 49/100, Validation Accuracy: 0.0439
# Epoch 50/100, Validation Accuracy: 0.0455
# Epoch 51/100, Validation Accuracy: 0.0467
# Epoch 52/100, Validation Accuracy: 0.0486
# Epoch 53/100, Validation Accuracy: 0.0507
# Epoch 54/100, Validation Accuracy: 0.0520
# Epoch 55/100, Validation Accuracy: 0.0532
# Epoch 56/100, Validation Accuracy: 0.0542
# Epoch 57/100, Validation Accuracy: 0.0559
# Epoch 58/100, Validation Accuracy: 0.0573
# Epoch 59/100, Validation Accuracy: 0.0593
# Epoch 60/100, Validation Accuracy: 0.0607
# Epoch 61/100, Validation Accuracy: 0.0616
# Epoch 62/100, Validation Accuracy: 0.0626
# Epoch 63/100, Validation Accuracy: 0.0648
# Epoch 64/100, Validation Accuracy: 0.0660
# Epoch 65/100, Validation Accuracy: 0.0677
# Epoch 66/100, Validation Accuracy: 0.0698
# Epoch 67/100, Validation Accuracy: 0.0714
# Epoch 68/100, Validation Accuracy: 0.0729
# Epoch 69/100, Validation Accuracy: 0.0747
# Epoch 70/100, Validation Accuracy: 0.0763
# Epoch 71/100, Validation Accuracy: 0.0770
# Epoch 72/100, Validation Accuracy: 0.0784
# Epoch 73/100, Validation Accuracy: 0.0803
# Epoch 74/100, Validation Accuracy: 0.0819
# Epoch 75/100, Validation Accuracy: 0.0845
# Epoch 76/100, Validation Accuracy: 0.0862
# Epoch 77/100, Validation Accuracy: 0.0876
# Epoch 78/100, Validation Accuracy: 0.0891
# Epoch 79/100, Validation Accuracy: 0.0908
# Epoch 80/100, Validation Accuracy: 0.0923
# Epoch 81/100, Validation Accuracy: 0.0946
# Epoch 82/100, Validation Accuracy: 0.0972
# Epoch 83/100, Validation Accuracy: 0.0984
# Epoch 84/100, Validation Accuracy: 0.1004
# Epoch 85/100, Validation Accuracy: 0.1020
# Epoch 86/100, Validation Accuracy: 0.1035
# Epoch 87/100, Validation Accuracy: 0.1055
# Epoch 88/100, Validation Accuracy: 0.1066
# Epoch 89/100, Validation Accuracy: 0.1083
# Epoch 90/100, Validation Accuracy: 0.1103
# Epoch 91/100, Validation Accuracy: 0.1117
# Epoch 92/100, Validation Accuracy: 0.1135
# Epoch 93/100, Validation Accuracy: 0.1153
# Epoch 94/100, Validation Accuracy: 0.1172
# Epoch 95/100, Validation Accuracy: 0.1179
# Epoch 96/100, Validation Accuracy: 0.1189
# Epoch 97/100, Validation Accuracy: 0.1204
# Epoch 98/100, Validation Accuracy: 0.1221
# Epoch 99/100, Validation Accuracy: 0.1237
# Epoch 100/100, Validation Accuracy: 0.1245
